# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ## Load the Model

# %%
model = tf.keras.models.load_model("dataset/object_detection.h5")

# %% [markdown]
# # Load Image

# %%
image = load_img(path="dataset/data/N1.jpeg")
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)

image1 = load_img(path="dataset/data/N1.jpeg", target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0 # convert into array and normalize output

# %%
# size of the image
image.shape
# Out:
# (1080, 1920, 3)

# %%
plt.figure(figsize=(8,6))
plt.imshow(image)
plt.title("Original Image without sizing")
plt.axis("off")
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
# size of the image1
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
# reshaping

test_arr = image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %% [markdown]
# ## Prediction

# %%
coords = model.predict(test_arr)
coords
# Out:
# 1/1 [==============================] - 4s 4s/step
# array([[0.5638953 , 0.70997876, 0.59156656, 0.65807414]], dtype=float32)

# %% [markdown]
# ## Denormalization

# %%
h,w,d = image.shape

# %%
denorm = np.array([w,w,h,h])
coords = coords * denorm

coords
# Out:
# array([[1082.67894745, 1363.15921783,  638.89188766,  710.72007179]])

# %%
coords = coords.astype(np.int32)
coords
# Out:
# array([[1082, 1363,  638,  710]])

# %% [markdown]
# ## Bounding Box

# %%
xmin, xmax, ymin, ymax = coords[0]

pt1 = (xmin, ymin)
pt2 = (xmax, ymax)

print(pt1, pt2)

cv2.rectangle(image, pt1, pt2, (0,255,0), 5)

plt.figure(figsize=(8,6))
plt.imshow(image)
plt.title("Prediction of Bounding Box")
plt.axis("off")
# Out:
# (1082, 638) (1363, 710)
# (-0.5, 1919.5, 1079.5, -0.5)

# %% [markdown]
# ## Pipeline

# %%
path="dataset/data/N1.jpeg"

def object_detection(path):
    # read image
    image = load_img(path) #PIL Object
    image = np.array(image, dtype=np.uint8) # 8 bit array (0,255)
    image1 = load_img(path, target_size=(224,224))
    
    # data preprocessing
    image_arr_224 = img_to_array(image1)/255.0 # convert into array and normalize output

    # get the shape
    h,w,d = image.shape

    # resize
    test_arr = image_arr_224.reshape(1,224,224,3)

    # prediction
    coords = model.predict(test_arr)

    # denormalize
    denorm = np.array([w,w,h,h])
    coords = coords * denorm
    coords = coords.astype(np.int32)

    xmin, xmax, ymin, ymax = coords[0]
    pt1 = (xmin, ymin)
    pt2 = (xmax, ymax)
    print(pt1, pt2)
    cv2.rectangle(image, pt1, pt2, (0,255,0), 5)
    
    return image, coords

# %%
img,coords = object_detection(path="dataset/data/N1.jpeg")

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.title("Prediction of Bounding Box")
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 198ms/step
# (1082, 638) (1363, 710)
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
img,coords = object_detection(path="dataset/data/N191.jpeg")

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.title("Prediction of Bounding Box")
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 187ms/step
# (410, 335) (533, 382)
# (-0.5, 649.5, 571.5, -0.5)

# %%
img,coords = object_detection(path="dataset/data/N191.jpeg")

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.title("Prediction of Bounding Box")
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 202ms/step
# (410, 335) (533, 382)
# (-0.5, 649.5, 571.5, -0.5)

# %% [markdown]
# # OCR - Optical Character Recognition

# %%
import pytesseract as pt

# %%
path="dataset/data/N1.jpeg"

img,coords = object_detection(path)

plt.figure(figsize=(8,6))
plt.imshow(img)
plt.title("Prediction of Bounding Box")
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 209ms/step
# (1082, 638) (1363, 710)
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
img = np.array(load_img(path))

xmin, xmax, ymin, ymax = coords[0]
roi = img[ymin:ymax, xmin:xmax]

plt.imshow(roi)
plt.title("Cropped Plate")
plt.axis("off")
# Out:
# (-0.5, 280.5, 71.5, -0.5)

# %% [markdown]
# ## Extract Text from the Plate

# %%
#img = cv2.imread("demo.png")
text = pt.image_to_string(roi)

print(text)

# %%
print(text)
